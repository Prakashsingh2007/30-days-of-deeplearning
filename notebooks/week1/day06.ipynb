# %%
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
y = iris.target

print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
import torch

X = torch.tensor(X, dtype=torch.float32)

y = torch.tensor(y, dtype=torch.long)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
x = torch.tensor(X, dtype=torch.float32)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
from torch.utils.data import TensorDataset, DataLoader
train_dataset = TensorDataset(x_train, y_train)
test_dataset = TensorDataset(x_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
import torch.nn as nn
model = nn.Sequential(
    nn.Linear(4, 16),
    nn.ReLU(),
    nn.Linear(16, 8),
    nn.ReLU(),
    nn.Linear(8, 3)
)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 100
for epoch in range(epochs):
    model.train()
    for batch_x, batch_y in train_loader:
        optimizer.zero_grad()
        outputs = model(batch_x)
        loss = loss_fn(outputs, batch_y)
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for batch_x, batch_y in test_loader:
            outputs = model(batch_x)
            _, predicted = torch.max(outputs.data, 1)
            total += batch_y.size(0)
            correct += (predicted == batch_y).sum().item()

    accuracy = 100 * correct / total
    print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}, Accuracy: {accuracy:.2f}%')
# Out:
# Epoch [1/100], Loss: 1.1018, Accuracy: 30.00%
# Epoch [2/100], Loss: 1.3013, Accuracy: 30.00%
# Epoch [3/100], Loss: 1.1182, Accuracy: 30.00%
# Epoch [4/100], Loss: 1.0705, Accuracy: 30.00%
# Epoch [5/100], Loss: 1.0834, Accuracy: 33.33%
# Epoch [6/100], Loss: 1.0649, Accuracy: 33.33%
# Epoch [7/100], Loss: 0.9457, Accuracy: 33.33%
# Epoch [8/100], Loss: 0.9752, Accuracy: 36.67%
# Epoch [9/100], Loss: 1.0011, Accuracy: 43.33%
# Epoch [10/100], Loss: 0.9875, Accuracy: 53.33%
# Epoch [11/100], Loss: 0.8532, Accuracy: 56.67%
# Epoch [12/100], Loss: 0.8387, Accuracy: 60.00%
# Epoch [13/100], Loss: 0.9133, Accuracy: 90.00%
# Epoch [14/100], Loss: 0.8111, Accuracy: 96.67%
# Epoch [15/100], Loss: 0.7947, Accuracy: 96.67%
# Epoch [16/100], Loss: 0.7607, Accuracy: 96.67%
# Epoch [17/100], Loss: 0.6859, Accuracy: 93.33%
# Epoch [18/100], Loss: 0.5725, Accuracy: 93.33%
# Epoch [19/100], Loss: 0.5521, Accuracy: 93.33%
# Epoch [20/100], Loss: 0.5247, Accuracy: 93.33%
# Epoch [21/100], Loss: 0.5603, Accuracy: 93.33%
# Epoch [22/100], Loss: 0.4614, Accuracy: 93.33%
# Epoch [23/100], Loss: 0.4046, Accuracy: 93.33%
# Epoch [65/100], Loss: 0.2003, Accuracy: 100.00%
# Epoch [66/100], Loss: 0.0399, Accuracy: 100.00%
# Epoch [67/100], Loss: 0.0372, Accuracy: 100.00%
# Epoch [68/100], Loss: 0.2160, Accuracy: 100.00%
# Epoch [69/100], Loss: 0.0280, Accuracy: 100.00%
# Epoch [70/100], Loss: 0.2796, Accuracy: 100.00%
# Epoch [71/100], Loss: 0.0231, Accuracy: 100.00%
# Epoch [72/100], Loss: 0.0295, Accuracy: 100.00%
# Epoch [73/100], Loss: 0.0755, Accuracy: 100.00%
# Epoch [74/100], Loss: 0.0853, Accuracy: 100.00%
# Epoch [75/100], Loss: 0.0667, Accuracy: 100.00%
# Epoch [76/100], Loss: 0.1306, Accuracy: 100.00%
# Epoch [77/100], Loss: 0.1093, Accuracy: 100.00%
# Epoch [78/100], Loss: 0.0146, Accuracy: 100.00%
# Epoch [79/100], Loss: 0.0286, Accuracy: 100.00%
# Epoch [80/100], Loss: 0.0654, Accuracy: 100.00%
# Epoch [81/100], Loss: 0.2063, Accuracy: 100.00%
# Epoch [82/100], Loss: 0.0381, Accuracy: 100.00%
# Epoch [83/100], Loss: 0.1194, Accuracy: 100.00%
# Epoch [84/100], Loss: 0.0441, Accuracy: 100.00%
# Epoch [85/100], Loss: 0.1917, Accuracy: 100.00%
# Epoch [86/100], Loss: 0.0136, Accuracy: 100.00%
# Epoch [87/100], Loss: 0.1327, Accuracy: 100.00%
# Epoch [88/100], Loss: 0.0166, Accuracy: 100.00%
# Epoch [89/100], Loss: 0.0131, Accuracy: 100.00%
# Epoch [90/100], Loss: 0.0196, Accuracy: 100.00%
# Epoch [91/100], Loss: 0.1950, Accuracy: 100.00%
# Epoch [92/100], Loss: 0.0430, Accuracy: 100.00%
# Epoch [93/100], Loss: 0.0478, Accuracy: 100.00%
# Epoch [94/100], Loss: 0.0513, Accuracy: 100.00%
# Epoch [95/100], Loss: 0.0058, Accuracy: 100.00%
# Epoch [96/100], Loss: 0.0542, Accuracy: 100.00%
# Epoch [97/100], Loss: 0.1249, Accuracy: 100.00%
# Epoch [98/100], Loss: 0.0447, Accuracy: 100.00%
# Epoch [99/100], Loss: 0.0427, Accuracy: 100.00%
# Epoch [100/100], Loss: 0.0081, Accuracy: 100.00%

# %%
sample = torch.tensor([
    [5.1,3.5,1.4,0.2]
], dtype=torch.float32)

sample = torch.tensor(
    scaler.transform(sample),
    dtype=torch.float32
)

model.eval()

with torch.no_grad():

    prediction = model(sample)

    predicted_class = prediction.argmax(dim=1)

print(predicted_class)
# Out:
# tensor([0])
