# %%
import torch
import torch.nn as nn   
a = [[1],[2],[3],[4],[5],[6],[7]]
b = [[1],[4],[7],[10],[13],[16],[19]]
x = torch.tensor(a, dtype=torch.float32)
y = torch.tensor(b, dtype=torch.float32)

# %%
model1 = nn.Linear(1,1)
loss_fn1 = nn.MSELoss()
optimizer1 = torch.optim.Adam(model1.parameters(), lr=0.01)

# %%
epochs = 1000
for epoch in range(epochs):
    # Forward pass: Compute predicted y by passing x to the model
    y_pred = model1(x)

    # Compute and print loss
    loss = loss_fn1(y_pred, y)
    
    # Zero gradients, perform a backward pass, and update the weights.
    optimizer1.zero_grad()
    loss.backward()
    optimizer1.step()

    if epoch % 100 == 0:
        print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')
# Out:
# Epoch 1/1000, Loss: 98.63663482666016
# Epoch 101/1000, Loss: 28.057086944580078
# Epoch 201/1000, Loss: 7.1923828125
# Epoch 301/1000, Loss: 3.4299442768096924
# Epoch 401/1000, Loss: 2.8216841220855713
# Epoch 501/1000, Loss: 2.508561849594116
# Epoch 601/1000, Loss: 2.209808111190796
# Epoch 701/1000, Loss: 1.9192174673080444
# Epoch 801/1000, Loss: 1.6433357000350952
# Epoch 901/1000, Loss: 1.3872439861297607

# %%
test = torch.tensor([[8.0]])
predicted = model1(test).item()
print(f'Prediction for input 8.0: {predicted:.4f}')
# Out:
# Prediction for input 8.0: 20.3857
